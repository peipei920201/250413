# %% [markdown]
# <a href="https://colab.research.google.com/github/peipei920201/250413/blob/main/lesson2_%E5%AD%97%E4%B8%B2%E6%8F%92%E8%A3%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"這是字串"
'這也是字串'
print('這是第一個數值:' + str(10) + "\n這是第一個數值:" + str(20.2))
#共1個引數值
display('這是第一個數值' + str(10) + "\n這是第一個數值" + str(20.2))
#display將\n顯示成其格式，所以沒有換行效果
print('這是第一個數值:', str(10),"\n這是第一個數值:",str(20.2))
#共4個引數值，引數之間存在空格
# Out:
# 這是第一個數值:10
# 這是第一個數值:20.2
# '這是第一個數值10\n這是第一個數值20.2'
# 這是第一個數值: 10
# 這是第一個數值: 20.2

# %% [markdown]
# ###字串插補

# %%
print(f"這是第一個數值:{10}\n這是第二個數值:{20}")
# Out:
# 這是第一個數值:10
# 這是第二個數值:20

# %%
print("'pei'")
print('"pei"')
#將引號當符號印出
#print(""pei"")此為錯誤寫法
# Out:
# 'pei'
# "pei"

# %%
# !python --version
#查看直譯器版本
# Out:
# Python 3.11.12
